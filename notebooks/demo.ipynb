# %% [markdown]
# # Video Stabilization Demo
#
# This notebook demonstrates the video stabilization capabilities of our package.
#
# ## Overview
#
# We'll show how to:
# 1. Create synthetic shaky videos
# 2. Apply different stabilization methods
# 3. Evaluate stabilization quality
# 4. Visualize results

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

from video_stabilization import VideoStabilizer
from video_stabilization.utils import (
    VideoProcessor, 
    MetricsCalculator,
    create_synthetic_shaky_video,
    set_seed
)

# Set random seed for reproducibility
set_seed(42)

print("Video Stabilization Demo")
print("=" * 30)
